# %%
import pandas as pd
df = pd.read_csv("clean_data_multiple_filter.csv")

df["Time (s) Run #4"]
df["Position (m) Run #4"].dropna()
# Out:
# 146    0.860
# 147    0.830
# 148    0.805
# 149    0.780
# 150    0.760
# 151    0.710
# 152    0.670
# 153    0.630
# 154    0.590
# 155    0.550
# 156    0.500
# 157    0.460
# 158    0.410
# 159    0.360
# 160    0.310
# 161    0.260
# 162    0.210
# 163    0.160
# 164    0.090
# 165    0.045
# 166    0.000
# Name: Position (m) Run #4, dtype: float64
