# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
coffee_df[["Time (s) Run #2","Position (m) Run #2"]].plot(x = "Time (s) Run #2" , y = "Position (m) Run #2", kind="line", grid=True)
# Out:
# <Axes: xlabel='Time (s) Run #2'>

# %%
coffee_df = pd.read_csv('data_for_coffee.csv')
#replaces NaNs with arbitrary values on given data frame
new_df = coffee_df.fillna(9)
def cleanData(coffee_df):
    num_columns = len(coffee_df.columns) #number of columns
    for pos_column in range(int(num_columns/4)): #there are 4 columns for this type of csv file






#Splitting df into 1 column
position_df = new_df['Position (m) Run #2']

#Function that returns the minimum value in position and its index
def minVal(position_df):
    index = 0
    min = position_df.at[0]
    for i in range(1, len(position_df)):
        curr = position_df.at[i]
        if curr < min:
            min = curr
            index = i
    return [min, index]
answer = minVal(position_df)

#Truncate df with respect to the index found in minVal
truncated_df = coffee_df.iloc[:120, :4]

truncated_df
# Out:
#      Time (s) Run #2  Position (m) Run #2  Velocity (m/s) Run #2  \
# 0               0.00                 0.97                    NaN
# 1               0.02                 1.01                   0.49
# 2               0.04                 0.99                  -0.05
# 3               0.06                 0.99                  -0.32
# 4               0.08                 0.98                  -0.21
# ..               ...                  ...                    ...
# 115             2.30                 0.26                  -2.72
# 116             2.32                 0.21                  -2.52
# 117             2.34                 0.15                  -1.80
# 118             2.36                 0.12                  -1.91
# 119             2.38                 0.13                  -2.28
#
#      Acceleration (m/s²) Run #2
# 0                           NaN
# 1                           NaN
# 2                        -20.25
# 3                         -6.69
# ...

# %% [markdown]
# # Progress

# %%
truncated_df[["Time (s) Run #2","Position (m) Run #2"]].plot(x = "Time (s) Run #2" , y = "Position (m) Run #2", kind="line", grid=True)
# Out:
# <Axes: xlabel='Time (s) Run #2'>
