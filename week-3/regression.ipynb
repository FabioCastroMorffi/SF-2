# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
grades_df = pd.read_csv('Student_Grades.csv')
# #new_df = grades_df.replace(np.nan, 'some value')
# grades_df.replace(np.nan, "NaN")
# grades_df.to_csv('Student_Grades.csv')

# %%
grades_df = grades_df.dropna()
xpoints = grades_df['Hours'].to_numpy()
ypoints = grades_df['Scores'].to_numpy()
plt.scatter(xpoints, ypoints, s  = 5)
plt.xlabel('Hours dedicated to studying')
plt.ylabel('Score')
plt.title('Hello')
# Out:
# Text(0.5, 1.0, 'Hello')

# %%
grades_df[grades_df['Grade'].str.contains('A')]
# Out:
#     Hours  Practice  TeamWork  MidTerm  FinalExam  Scores Grade
# 3     8.5       3.7       1.2      7.0        7.7    75.0     A
# 6     9.2       4.8       3.0      8.0        9.0    88.0     A
# 8     8.3       5.1       3.5      8.0        8.3    81.0     A
# 10    7.7       4.9       4.5      8.0        8.7    85.0     A
# 11    5.9       3.1       2.1      6.0        6.4    62.0     A
# 15    8.9       6.2       6.0      9.0        9.7    95.0     A
# 18    6.1       2.0       3.2      6.0        6.9    67.0     A
# 19    7.4       2.5       3.0      7.0        7.1    69.0     A
# 23    6.9       5.1       3.8      7.0        7.8    76.0     A
# 24    7.8       5.8       4.5      8.0        8.8    86.0     A

# %%
grades_df['Midterm'].min() #minimum
grades_df["Final Exam"].max()
grades_df['FinalExam'].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Midterm'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 grades_df['Midterm'].min() #minimum
# ...

# %% [markdown]
# change numerical vals to strings
# set index to 'Hours'
# slice
# rename columns
# rename the index column

# %%
#grades_df['Hours'] = grades_df['Hours'].astype(str)
new_df2 = grades_df.set_index('Hours').sort_values('Hours')
new_df2.loc[1.1:5.5]
new_df3 = grades_df.rename(columns = {'Hours': 'Hours Studied'})#for not index column
new_df2 = grades_df.rename_axis('Hours Studied')
# Out:
#     Unnamed: 0  Hours Studied  Practice  TeamWork  MidTerm  FinalExam  Scores  \
# 0            0            2.5       0.5       0.0      2.0        2.3    21.0
# 1            1            5.1       1.5       0.5      4.0        4.9    47.0
# 2            2            3.2       1.0       0.5      3.0        2.9    27.0
# 3            3            8.5       3.7       1.2      7.0        7.7    75.0
# 4            4            3.5       1.2       0.3      3.0        3.2    30.0
# 5            5            1.5       0.2       0.0      2.0        2.2    20.0
# 6            6            9.2       4.8       3.0      8.0        9.0    88.0
# 7            7            5.5       3.2       2.0      6.0        6.2    60.0
# 8            8            8.3       5.1       3.5      8.0        8.3    81.0
# 9            9            2.7       1.5       0.0      3.0        2.7    25.0
# 10          10            7.7       4.9       4.5      8.0        8.7    85.0
# ...

# %%
lst =grades_df.index[grades_df['Hours'] == 2.5].tolist()
lst
index = lst[1]
grades_df.iloc[index]
grades_df.iloc[index:index+6]
# Out:
#     Unnamed: 0  Hours  Practice  TeamWork  MidTerm  FinalExam  Scores Grade
# 16          16    2.5       1.6       1.0      3.0        3.2    30.0     C
# 17          17    1.9       0.9       0.5      2.0        2.6    24.0     C
# 18          18    6.1       2.0       3.2      6.0        6.9    67.0     A
# 19          19    7.4       2.5       3.0      7.0        7.1    69.0     A
# 20          20    2.7       3.0       1.2      3.0        3.2    30.0     C
# 21          21    4.8       2.9       2.1      5.0        5.6    54.0     B

# %%
new_df = grades_df.set_index('Hours').sort_values('Hours')
new_df.loc[1.1:2, ['Midterm', 'FinalExam','Grade']]

new_df.at[1.1, 'FinalExam']
grades_df.iat[2, 4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 2
#       1 new_df = grades_df.set_index('Hours').sort_values('Hours')
# ----> 2 new_df.loc[1.1:2, ['Midterm', 'FinalExam','Grade']]
#
# File /usr/lib/python3.13/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File /usr/lib/python3.13/site-packages/pandas/core/indexing.py:1377, in _LocIndexer._getitem_tuple(self, tup)
#    1374 if self._multi_take_opportunity(tup):
#    1375     return self._multi_take(tup)
# -> 1377 return self._getitem_tuple_same_dim(tup)
#
# ...

# %% [markdown]
# - HMW write a snippet of Python code that goes through the values of coulumn 'Score' and determines the minimum score (loop, update min as u go)

# %%
scores_df = grades_df['Scores']
min = int(scores_df.at[0])

for i in range(1, len(scores_df)):
    curr = int(scores_df.at[i])
    if curr < min:
        min = curr
        
print(min)
# Out:
# 17

# %% [markdown]
# # Regression fit

# %%
scores_df.at[2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 scores_df.iat[27]
#
# File /usr/lib/python3.13/site-packages/pandas/core/indexing.py:2527, in _ScalarAccessIndexer.__getitem__(self, key)
#    2524         raise ValueError("Invalid call for scalar access (getting)!")
#    2526 key = self._convert_key(key)
# -> 2527 return self.obj._get_value(*key, takeable=self._takeable)
#
# File /usr/lib/python3.13/site-packages/pandas/core/series.py:1234, in Series._get_value(self, label, takeable)
#    1221 """
#    1222 Quickly retrieve single value at passed index label.
#    1223
#    (...)
#    1231 scalar value
#    1232 """
#    1233 if takeable:
# -> 1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
#    1237 loc = self.index.get_loc(label)
#
# ...

# %%
plt.scatter(xpoints,ypoints,s = 5)
plt.xlim(0,10)
plt.ylim(0,100)

#Create polynomial function (1st way)

#coeff = np.polyfit(xpoints,ypoints, deg = 1)
#print(coeff)
#best_fit_function = np.poly1d(coeff)
#plt.plot(xpoints, best_fit_function(xpoints), label = 'regression fit', color = 'red')

# second

b, a = np.polyfit(xpoints, ypoints, deg = 1) #b is a slope, a is y intercept
xseq = np.linspace(5,10)
plt.plot(xseq, b *xseq+a, c ='red')
